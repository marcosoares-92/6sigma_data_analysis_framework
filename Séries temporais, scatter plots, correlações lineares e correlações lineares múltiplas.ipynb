# %%
## Análise dinâmica de dados - Séries temporais, scatter plots, correlações lineares e correlações lineares múltiplas 

## CÉLULA 1: Instruções de carregamento do arquivo e bibliotecas a ser importadas

""""
    Para executar uma CÉLULA, pressione o botão "Run" no topo, com a CÉLULA selecionada, ou pressione:
    
    Shift + Enter

-Se seus dados estiverem em um arquivo xlsx utilize a CÉLULA 2

-Se seus dados estiverem em um arquivo csv contendo cabeçalhos, utilize a CÉLULA 3

-Se seus dados estiverem em um arquivo csv sem cabeçalhos, utilize a CÉLULA 4

-Utilize apenas a CÉLULA correta
-Substitua o texto entre aspas na variável "caminho" pelo endereço do arquivo em sua máquina.

EXECUTE ESTA CÉLULA ANTES DE PROSSEGUIR

EXECUTE APENAS UMA CÉLULA POR VEZ

-Caso deseje apagar a saída de uma célula carregada, mas não deseje carregar uma nova saída, vá à aba superior, escolha o ícone
do teclado (open the command palette/ jupyter-notebook command group) e selecione clear cell output.

@author: Marco César Prado Soares, MSc.
Especialista Lean Six Sigma Master Black Belt, Eng. Químico, MSc. Eng. Mecatrônica (instrumentação) 
Marco.Soares@br.ey.com; marcosoares.feq@gmail.com
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## CÉLULA 2: dados em arquivo xlsx

caminho = "D:\Drive\FM2S\EAD\Green Belt em Python\Machine Learning - módulo 2 - ANN regression\ANN.1 - Apartment price analysis\prices_apartments.xlsx"
dataset = pd.read_excel(caminho)

dataset
#SIGA PARA A CÉLULA 5

# %%
## CÉLULA 3: dados em arquivo csv com cabeçalho

caminho = "D:\Drive\FM2S\EAD\Green Belt em Python\Machine Learning - módulo 3 - ANN classification\ANN.Class - 2 - advertising campaign\delivery_app_data.csv"
dataset = pd.read_csv(caminho)

dataset
#SIGA PARA A CÉLULA 5

# %%
## CÉLULA 4: dados em arquivo csv sem cabeçalho

caminho = "D:\Drive\FM2S\EAD\Green Belt em Python\Machine Learning - módulo 2 - ANN regression\ANN.4 - Boston housing price\housing_boston_data.txt"
dataset = pd.read_csv(caminho, delim_whitespace=True, header=None)

#here, the dataset is in a textfile. In these cases, use delim_withespace = True
#or df = pd.read_fwf('output_list.txt')
#since data has no Head, keep header = None
#if there is Head, eliminate ‘header’ from the arguments of the function

dataset
#SIGA PARA A CÉLULA 5

# %%
## CÉLULA 5: Eliminar linhas com entradas nulas

"""
-Utilize esta CÉLULA apenas se desejar limpar as entradas nulas da sua base de dados

-Esta CÉLULA eliminará todas as linhas contendo entradas nulas. Caso NÃO DESEJE ISTO, vá direto à CÉLULA 6, sem executar esta
célula.
"""

dataset = dataset.dropna(axis=0)
dataset
#SIGA PARA A CÉLULA 6

# %% [markdown]
# # CÉLULA 6: Instruções Gerais
#
# ### ATENÇÃO: NÃO EXECUTE ESTA CÉLULA - Ela contém apenas texto explicativo
#
# Este notebook destina-se à análise de dados temporais ou dados possivelmente correlacionados (Y x X). À seguir, são dadas as análises disponíveis. Siga à célula correspondente à análise desejada:
#
# ## 1) Séries temporais
#
# - Aqui será construído o gráfico de linhas e/ou pontos correspondente à série temporal. Utilize este gráfico APENAS SE seus dados foram coletados sequencialmente.
# - Este sistema não pode ser utilizado para obtenção de correlações lineares.
# - Até 6 séries de dados diferentes (6 conjuntos de dados xy) podem ser analisados simultaneamente.
#
# Siga para as CÉLULAS 7 a 9.
# ----------------------------------------
#
# _______________________________________________________________________________________________________________________________
# _______________________________________________________________________________________________________________________________
# _______________________________________________________________________________________________________________________________
#
# ## 2) Scatter plots
#
# - Aqui será construído o gráfico de dispersão XY, que pode representar qualquer tipo de correlação, incluindo correlações temporais.
# - Até 6 séries de dados diferentes (6 conjuntos de dados xy) podem ser analisados simultaneamente.
# - Este sistema é capaz de obter as equações das retas correspondentes às regressões lineares de cada um dos conjuntos de dados; calcular os coeficientes de correlação R² de cada uma das curvas; e construir os gráficos das retas junto ao scatter plot original.
#
# Siga para as CÉLULAS 10 a 12.
# ----------------------------------------
#
# _______________________________________________________________________________________________________________________________
# _______________________________________________________________________________________________________________________________
# _______________________________________________________________________________________________________________________________
#
# ## 3) Regressão linear múltipla
#
# - Este sistema é capaz de obter correlação linear múltipla para até 6 variáveis simultâneas, calculando a equação e o coeficiente de correlação R² ajustado.
# - Atenção: este tipo de correlação possui alto risco de overfitting, quando o modelo representa muito bem os dados de teste/experimentais, mas responde mal a mudanças nestes dados.
# - Para reduzir este risco, o ideal é utilizar termos de penalizações e dividir os dados entre treino e teste de forma aleatória, o que é tipicamente realizado pelos algoritmos de aprendizado de máquina (Machine Learning).
#
# Siga para as CÉLULAS 13 a 15.
# ----------------------------------------

# %%
## CÉLULA 7: Função de avaliação das séries temporais

#Execute esta CÉLULA para carregar a função

def serie_temporal (x1 = None, y1 = None, x2 = None, y2 = None, x3 = None, y3 = None, x4 = None, y4 = None, x5 = None, y5 = None, x6 = None, y6 = None, grid = True, add_splines_lines = True, add_scatter_dots = False, lab1 = None, lab2 = None, lab3 = None, lab4 = None, lab5 = None, lab6 = None, titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None):
    
    import matplotlib.pyplot as plt
    
    if (add_splines_lines == True):
        line_value = '-'
    else:
        line_value = ''
    
    if (add_scatter_dots == True):
        marker_value = 'o'
    else:
        marker_value = ''
    
    fig = plt.figure()
    ax = fig.add_subplot()
    
    if not (lab1 is None):
        
        label_1 = lab1
    
    else:
        label_1 = "Y1"

    if not (x1 is None):
        ax.plot(x1, y1, linestyle = line_value, marker = marker_value, color='blue', label=label_1)
    
    if not (x2 is None):
        #roda apenas se ambos estiverem presentes
        if not (lab2 is None):
            label_2 = lab2
        else:
            label_2 = "Y2"
        
        ax.plot(x2, y2, linestyle = line_value, marker = marker_value, color='red', label=label_2)
    
    if not (x3 is None):
                
        if not (lab3 is None):
            label_3 = lab3
        else:
            label_3 = "Y3"
        
        ax.plot(x3, y3, linestyle = line_value, marker = marker_value, color='green', label=label_3)
    
    if not (x4 is None):
                
        if not (lab4 is None):
            label_4 = lab4
        else:
            label_4 = "Y4"
        
        ax.plot(x4, y4, linestyle = line_value, marker = marker_value, color='black', label=label_4)
    
    if not (x5 is None):
               
        if not (lab5 is None):
            label_5 = lab5
        else:
            label_5 = "Y5"
        
        ax.plot(x5, y5, linestyle = line_value, marker = marker_value, color='magenta', label=label_5)
   
    if not (x6 is None):
               
        if not (lab6 is None):
            label_6 = lab6
        else:
            label_6 = "Y6"
        
        ax.plot(x6, y6, linestyle = line_value, marker = marker_value, color='yellow', label=label_6)
   
    if not (titulo_do_grafico is None):
        #titulo do grafico
        ax.set_title(titulo_do_grafico) 
    
    if not (titulo_eixo_horizontal is None):
        #Titulo do eixo X
        ax.set_xlabel(titulo_eixo_horizontal)
    
    if not (titulo_eixo_vertical is None):
        #Titulo do eixo Y
        ax.set_ylabel(titulo_eixo_vertical)
    
    ax.grid(grid)
    ax.legend()
    plt.show()

# %% [markdown]
# # CÉLULA 8: Gráfico de serie temporal para até 6 series simultaneas
#
# ### ATENÇÃO: NÃO EXECUTE ESTA CÉLULA - Ela contém apenas texto explicativo
#
# ## Instrução: separe os dados em listas x e y. Isto pode ser feito pela filtragem dos resultados.
#
# - ESTA FUNÇÃO MOSTRARÁ TODAS AS SÉRIES EM UM MESMO GRÁFICO. Caso deseje separar em vários gráficos, chame a função várias vezes.
#
# - Você não precisa preencher em ordem, apenas os x e y correspondentes devem ser coerentes.
# Exemplo: caso você deseje plotar dois conjuntos x1,y1 e x2,y2, e deseje ver os conjuntos em verde e magenta, respectivamente, coloque os dados x1,y1 nos campos indicados como x3,y3, e coloque os dados x2,y2 nos campos da função indicados como x5,y5.
#
# - Como explicado abaixo, cada campo da função está associado a uma cor, de modo que você pode escolher os campos de acordo com as cores que deseja observar.
#
# - NAO DEIXE NENHUM CAMPO SEM MARCAÇÃO E NEM OMITA NENHUMA VARIÁVEL. CASO NÃO A USE, MANTENHA '=None'. Exemplo:
#
#         x1 = None, y1 = None, x2 = x2, y2 = y2,...
#
#  NOTE NESTE EXEMPLO: mesmo que o nome da lista seja x1, x2, ..., ou x6, y1, y2, ... , ou y6, é NECESSÁRIO ESCREVER:
#
#         x1 = x1, y2 = y2
#
#  Logicamente, se x1 receberá a lista x, y1 receberá a lista y (ou qualquer outro nome), você deve declarar o nome da lista correta:
#
#         x1 = x, y1 = y, etc.
#
# - Caso o eixo X seja o mesmo, repita a indicação varias vezes
# Exemplo:
#
#         x1 = x, x2 = x, x3 = x, x4 = x, x5 = x, x6 = x
#
# - Caso deseje fornecer titulos ao grafico e aos eixos, forneça eles entre aspas
# exemplo:
#
#         titulo_do_grafico = "Série temporal", titulo_eixo_horizontal = "X", titulo_eixo_vertical = "Y"
#
# - Coloque labels (entre aspas) caso deseje identificar as series.
# Exemplo:
#
#         lab1 = "Loja 1", lab2 = "Loja 2", caso representem séries de duas lojas
#
# - Caso deseje linhas de grade, mantenha
#
#         grid = True
#
# - Caso não deseje, mude para
#
#         grid = False
#
# - Caso deseje ver as retas (splines) ligando os pontos da série, mantenha
#
#         add_splines_lines = True.
#
# - Caso deseje remover as linhas, mude para
#
#         add_splines_lines = False.
#
# - Caso não deseje ver os pontos (dispersão/scatter plot), mas tão somente as linhas (deixando o gráfico menos poluído), mantenha
#
#         add_scatter_dots = False.
#
# - Caso deseje ver os pontos ao término de cada linha, mude para
#
#        add_scatter_dots = True
#
# - Note que os valores True e False devem ser escritos exatamente desta forma, primeira letra em maiúscula, e demais minúsculas, e não devem ser colocados entre aspas.
#
# - Note que, como todos os valores são definidos como None, você pode fazer o input em qualquer série, de modo a criar gráficos com diferentes cores:
#
#         x1, y1, lab1: série em azul
#         x2, y2, lab2: série em vermelho
#         x3, y3, lab3: série em verde
#         x4, y4, lab4: série em preto
#         x5, y5, lab5: série em magenta
#         x6, y6, lab6: série em amarelo
#
# ###### PORÉM, MAIS UMA VEZ: As séries não utilizadas devem ser mantidas em = None
#
# Exemplos de como chamar a função: note que todos os campos são preenchidos.
#
# - Não há problema em preencher 'labs' que não serão usadas (este é o único campo que aceita preenchimento "a mais", porque se trata apenas da legenda do gráfico)
#
#         serie_temporal (x1 = None, y1 = None, x2 = x2, y2 = y, x3 =x3, y3 = y, x4 = x4, y4 = y, x5 = x5, y5 = y, x6 = x6, y6 = y, grid = True, add_splines_lines = True, add_scatter_dots = True, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#
#         serie_temporal (x1 = x1, y1 = y, x2 = x2, y2 = y, x3 =x3, y3 = y, x4 = x4, y4 = y, x5 = x5, y5 = y,  grid = True, add_splines_lines = False, add_scatter_dots = True, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#
#         serie_temporal (x1 = x1, y1 = y, x2 = x2, y2 = y, x3 =x3, y3 = y, x4 = x4, y4 = y, grid = True, add_splines_lines = False, add_scatter_dots = True, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#
#         serie_temporal (x1 = x1, y1 = y, x2 = x2, y2 = y, x3 =x3, y3 = y, grid = True, add_splines_lines = False, add_scatter_dots = True, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#
#         serie_temporal (x1 = x1, y1 = y, x2 = x2, y2 = y, grid = True, add_splines_lines = False, add_scatter_dots = True, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#
#         serie_temporal (x1 = x1, y1 = y, grid = True, add_splines_lines = False, add_scatter_dots = True, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)

# %%
## CÉLULA 9: CONSTRUÇÃO DO GRÁFICO PARA SEUS DADOS

#DEFINA A VARIAVEL x1. Basta substituir o valor entre aspas pelo nome da coluna onde está X1:
x1 = dataset['X1']

#DEFINA A VARIAVEL y1. Basta substituir o valor entre aspas pelo nome da coluna onde está Y1:
y1 = dataset['Y1']

# Na função, substitua um dos valores = None das variáveis x1, x2, ..., x6 por = x1, e o correspondente = None da variável y
#por =y1, de acordo com a cor desejada para o gráfico (como explicado nas instruções acima). 
#O recomendável é colocar x1 = x1, y1 = y1.

#OBSERVAÇÃO: Caso os dados não estejam separados por colunas desta forma, crie séries para armazenar separadamente os dados x,y
#Isto pode ser feito por meio de funções de agregação.
#Clique no botão + no menu superior para criar uma célula que realize esta etapa. Se a célula estiver abaixo da CELL_9, basta
#clicar na seta para cima, do menu superior

"""RÓTULOS, labels e outros valores possíveis

- Existem outras variáveis (x2,y2, x3, y3... etc)? Se existirem, copie e cole as linhas abaixo após as aspas, i.e.,
fora da seção de comentários. Troque os valores entre aspas dentro dos colchetes pelos nomes corretos das colunas no dataset.
Não se equeça de substituir o valor None na função pelo nome correspondente (ou seja: x2 = None deverá ser substituído por 
x2 = x2, ...  e etc, de acordo com os campos presentes e com as cores desejadas).

x2 = dataset['X2']
y2 = dataset['Y2']
x3 = dataset['X3']
y3 = dataset['Y3']
x4 = dataset['X4']
y4 = dataset['Y4']
x5 = dataset['X5']
y5 = dataset['Y5']
x6 = dataset['X6']
y6 = dataset['Y6']

- Existem legendas/rótulos/labels que identifiquem os dados? Se existirem, declare-os entre aspas, conforme as instruções acima.
Por exemplo, lab1 = "loja 1".

"""

serie_temporal (x1 = None, y1 = None, x2 = None, y2 = None, x3 = None, y3 = None, x4 = None, y4 = None, x5 = None, y5 = None, x6 = None, y6 = None, grid = True, add_splines_lines = True, add_scatter_dots = False, lab1 = None, lab2 = None, lab3 = None, lab4 = None, lab5 = None, lab6 = None, titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
  

"""
Substitua os demais campos None de acordo com as instruções dadas na CÉLULA 8.
- Os títulos e legendas devem ser fornecidos como um texto entre aspas

"""

# %%
## CÉLULA 10: Função de avaliação dos diagramas de dispersão (scatter plots) e avaliação de correlações lineares

#Execute esta CÉLULA para carregar a função

def scatter_plot_lin_reg (x1 = None, y1 = None, x2 = None, y2 = None, x3 = None, y3 = None, x4 = None, y4 = None, x5 = None, y5 = None, x6 = None, y6 = None, show_linear_reg = True, grid = True, add_splines_lines = True, lab1 = None, lab2 = None, lab3 = None, lab4 = None, lab5 = None, lab6 = None, titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None): 
    
    import matplotlib.pyplot as plt
    import pandas as pd
    from scipy import stats
    
    if (add_splines_lines == True):
        line_value = '-'
    else:
        line_value = ''
    
    if (show_linear_reg == True):
        estatisticas = []
        estatisticas.append("Equação da reta:")
        estatisticas.append("R² = ")
    
    fig = plt.figure()
    ax = fig.add_subplot()
    
    if not (x1 is None):
        
        if not (lab1 is None):
            label_1 = lab1
        else:
            label_1 = "Y1 x X1"
        
        #falsa negativa: passa se os valores nao forem nulos
        ax.plot(x1, y1, linestyle = line_value, marker = 'o', color='blue', label=label_1)
        
        if (show_linear_reg == True):
            reta1 = []
            #Calculo da regressao linear:
            reg1 = stats.linregress(x1, y1)
            #organizar os X, para que os splines formem a reta correta
            x_reg1 = x1.sort_values()
            x_reg1 = x_reg1.reset_index(drop = True)
            #curva obtida:
            y_reg1 = (reg1).intercept + (reg1).slope*(x_reg1)
            #gerar string da reta
            string1 = "y = %.2f*x + %.2f" %((reg1).slope, (reg1).intercept)
            reta1.append(string1)
            #calcular R2
            r_sq1 = (reg1).rvalue**2
            reta1.append(r_sq1)
            print("\nEquação da reta 1: " + string1)
            #concatena as strings
            print("\nR² (reta 1) = %.4f" %(r_sq1))
            string_label1 = 'Linear regression: ' + label_1
            ax.plot(x_reg1, y_reg1,  linestyle='-', marker='', color='blue', label = string_label1)
    
    if not (x2 is None):
        #roda apenas se ambos estiverem presentes
                
        if not (lab2 is None):
            label_2 = lab2
        else:
            label_2 = "Y2"
        
        ax.plot(x2, y2, linestyle = line_value, marker = 'o', color='red', label=label_2)    
        
        if (show_linear_reg == True):
            reta2 = []
            #Calculo da regressao linear:
            reg2 = stats.linregress(x2, y2)
            #organizar os X, para que os splines formem a reta correta
            x_reg2 = x2.sort_values()
            x_reg2 = x_reg2.reset_index(drop = True)
            #curva obtida:
            y_reg2 = (reg2).intercept + (reg2).slope*(x_reg2)
            #gerar string da reta
            string2 = "y = %.2f*x + %.2f" %((reg2).slope, (reg2).intercept)
            reta2.append(string2)
            #calcular R2
            r_sq2 = (reg2).rvalue**2
            reta2.append(r_sq2)
            print("\nEquação da reta 2: " + string2)
            #concatena as strings
            print("\nR² (reta 2) = %.4f" %(r_sq2))
            string_label2 = 'Linear regression: ' + label_2
            ax.plot(x_reg2, y_reg2,  linestyle='-', marker='', color='red', label = string_label2)
        
    if not (x3 is None):
                
        if not (lab3 is None):
            label_3 = lab3
        else:
            label_3 = "Y3"
        
        ax.plot(x3, y3, linestyle = line_value, marker = 'o', color='green', label=label_3)
        
        if (show_linear_reg == True):
            reta3 = []
            #Calculo da regressao linear:
            reg3 = stats.linregress(x3, y3)
            #organizar os X, para que os splines formem a reta correta
            x_reg3 = x3.sort_values()
            x_reg3 = x_reg3.reset_index(drop = True)
            #curva obtida:
            y_reg3 = (reg3).intercept + (reg3).slope*(x_reg3)
            #gerar string da reta
            string3 = "y = %.2f*x + %.2f" %((reg3).slope, (reg3).intercept)
            reta3.append(string3)
            #calcular R2
            r_sq3 = (reg3).rvalue**2
            reta3.append(r_sq3)
            print("\nEquação da reta 3: " + string3)
            #concatena as strings
            print("\nR² (reta 3) = %.4f" %(r_sq3))
            string_label3 = 'Linear regression: ' + label_3
            ax.plot(x_reg3, y_reg3,  linestyle='-', marker='', color='green', label = string_label3)
        
    if not (x4 is None):
                
        if not (lab4 is None):
            label_4 = lab4
        else:
            label_4 = "Y4"
        
        ax.plot(x4, y4, linestyle = line_value, marker = 'o', color='black', label=label_4)
        
        if (show_linear_reg == True):
            reta4 = []
            #Calculo da regressao linear:
            reg4 = stats.linregress(x4, y4)
            #organizar os X, para que os splines formem a reta correta
            x_reg4 = x4.sort_values()
            x_reg4 = x_reg4.reset_index(drop = True)
            #curva obtida:
            y_reg4 = (reg4).intercept + (reg4).slope*(x_reg4)
            #gerar string da reta
            string4 = "y = %.2f*x + %.2f" %((reg4).slope, (reg4).intercept)
            reta4.append(string4)
            #calcular R2
            r_sq4 = (reg4).rvalue**2
            reta4.append(r_sq4)
            print("\nEquação da reta 4: " + string4)
            #concatena as strings
            print("\nR² (reta 4) = %.4f" %(r_sq4))
            string_label4 = 'Linear regression: ' + label_4
            ax.plot(x_reg4, y_reg4,  linestyle='-', marker='', color='black', label = string_label4)
    
    if not (x5 is None):
               
        if not (lab5 is None):
            label_5 = lab5
        else:
            label_5 = "Y5"
        
        ax.plot(x5, y5, linestyle = line_value, marker = 'o', color='magenta', label=label_5)
        
        if (show_linear_reg == True):
            reta5 = []
            #Calculo da regressao linear:
            reg5 = stats.linregress(x5, y5)
            #organizar os X, para que os splines formem a reta correta
            x_reg5 = x5.sort_values()
            x_reg5 = x_reg5.reset_index(drop = True)
            #curva obtida:
            y_reg5 = (reg5).intercept + (reg5).slope*(x_reg5)
            #gerar string da reta
            string5 = "y = %.2f*x + %.2f" %((reg5).slope, (reg5).intercept)
            reta5.append(string5)
            #calcular R2
            r_sq5 = (reg5).rvalue**2
            reta5.append(r_sq5)
            print("\nEquação da reta 5: " + string5)
            #concatena as strings
            print("\nR² (reta 5) = %.4f" %(r_sq5))
            string_label5 = 'Linear regression: ' + label_5
            ax.plot(x_reg5, y_reg5,  linestyle='-', marker='', color='magenta', label = string_label5)
   
    if not (x6 is None):
               
        if not (lab6 is None):
            label_6 = lab6
        else:
            label_6 = "Y6"
        
        ax.plot(x6, y6, linestyle = line_value, marker = 'o', color='yellow', label=label_6)
            
        if (show_linear_reg == True):
            reta6 = []
            #Calculo da regressao linear:
            reg6 = stats.linregress(x6, y6)
            #organizar os X, para que os splines formem a reta correta
            x_reg6 = x6.sort_values()
            x_reg6 = x_reg6.reset_index(drop = True)
            #curva obtida:
            y_reg6 = (reg6).intercept + (reg6).slope*(x_reg6)
            #gerar string da reta
            string6 = "y = %.2f*x + %.2f" %((reg6).slope, (reg6).intercept)
            reta6.append(string6)
            #calcular R2
            r_sq6 = (reg6).rvalue**2
            reta6.append(r_sq6)
            print("\nEquação da reta 6: " + string6)
            #concatena as strings
            print("\nR² (reta 6) = %.4f" %(r_sq6))
            string_label6 = 'Linear regression: ' + label_6
            ax.plot(x_reg6, y_reg6,  linestyle='-', marker='', color='yellow', label = string_label6)
   
    if not (titulo_do_grafico is None):
        #titulo do grafico
        ax.set_title(titulo_do_grafico) 
    
    if not (titulo_eixo_horizontal is None):
        #Titulo do eixo X
        ax.set_xlabel(titulo_eixo_horizontal)
    
    if not (titulo_eixo_vertical is None):
        #Titulo do eixo Y
        ax.set_ylabel(titulo_eixo_vertical)
    
    ax.grid(grid)
    ax.legend()
    plt.show()
    
    if (show_linear_reg == True):
        
        if not (x2 is None):
            
            if not (x3 is None):
                
                if not (x4 is None):
                    
                    if not (x5 is None):
                        
                        if not (x6 is None):
                            #todos estao presentes
                            d = {'Estatísticas': estatisticas,
                                 label_1: reta1,
                                 label_2: reta2,
                                 label_3: reta3,
                                 label_4: reta4,
                                 label_5: reta5,
                                 label_6: reta6}
                        
                        else:
                            #apenas 5 estão presentes:
                            d = {'Estatísticas': estatisticas,
                                 label_1: reta1,
                                 label_2: reta2,
                                 label_3: reta3,
                                 label_4: reta4,
                                 label_5: reta5}
                    
                    else:
                        #apenas 4 estão presentes:
                        d = {'Estatísticas': estatisticas,
                             label_1: reta1,
                             label_2: reta2,
                             label_3: reta3,
                             label_4: reta4}
                
                else:
                    #apenas 3 estão presentes:
                    d = {'Estatísticas': estatisticas,
                         label_1: reta1,
                         label_2: reta2,
                         label_3: reta3}
            
            else:
                #apenas 2 estão presentes:
                d = {'Estatísticas': estatisticas,
                     label_1: reta1,
                     label_2: reta2}
        
        else:
            #apenas 1 esta presente:
            d = {'Estatísticas': estatisticas,
                 label_1: reta1}
        
        lin_reg_summary = pd.DataFrame(data = d)
        
        return lin_reg_summary

# %% [markdown]
# # CÉLULA 11: Gráfico de dispersão (scatter plot), com ou sem regressão linear
#
# ### ATENÇÃO: NÃO EXECUTE ESTA CÉLULA - Ela contém apenas texto explicativo
#
# ATENÇÃO: Caso deseje obter as regressões lineares, mantenha
#
#     show_linear_reg = True.
#
# Neste caso, será gerado um dataframe com as equações de correlação linear de cada um dos conjuntos de dados,
# juntamente com o valor de R². Neste caso, você precisa declarar um dataframe para receber os dados:
#
#     lin_reg_summary = scatter_plot_lin_reg(.....)
#
# - ESTA FUNÇÃO MOSTRARÁ TODAS AS SÉRIES EM UM MESMO GRÁFICO. Caso deseje separar em vários gráficos, chame a função várias vezes.
#
# -CASO DESEJE OBTER AS CORRELAÇÕES LINEARES y = a*x + b:
#
# Ao contrário da função de séries temporais, neste caso será necessário PREENCHER SEQUENCIALMENTE OS CAMPOS X1,Y1 até X6,Y6.
#
# - Caso contrário, o dataframe com as regressões não será gerado, ou será gerado de forma incompleta.
#
# - Em caso de chamar múltiplos gráficos, certifique-se de ter declarado todos os dataframes.
#
# - NAO DEIXE NENHUM CAMPO SEM MARCAÇÃO E NEM OMITA NENHUMA VARIÁVEL. CASO NÃO A USE, MANTENHA '=None'. Exemplo:
#
#         x1 = None, y1 = None, x2 = x2, y2 = y2,...
#
# NOTE NESTE EXEMPLO: mesmo que o nome da lista seja x1, x2, ..., ou x6, y1, y2, ... , ou y6, é NECESSÁRIO ESCREVER:
#
#         x1 = x1, y2 = y2
#
# Logicamente, se x1 receberá a lista x, y1 receberá a lista y (ou qualquer outro nome), você deve declarar o nome da lista correta: x1 = x, y1 = y, etc.
#
# - Note que no exemplo em que x1 = None, y1 = None e os outros valores são usados, o dataframe com as regressões NÃO É GERADO.
#
# - Caso o eixo X seja o mesmo, repita a indicação varias vezes
#
#       Exemplo: x1 = x, x2 = x, x3 = x, x4 = x, x5 = x, x6 = x
#
# - Caso deseje fornecer títulos ao gráfico e aos eixos, forneça eles entre aspas
#
#         exemplo: titulo_do_grafico = "Série temporal", titulo_eixo_horizontal = "X",
#         titulo_eixo_vertical = "Y"
#
# - Coloque labels (entre aspas) caso deseje identificar as séries.
#
#         Exemplo: lab1 = "Loja 1", lab2 = "Loja 2", caso representem séries de duas lojas
#
# - Caso deseje linhas de grade, mantenha grid = True
# Caso não deseje, mude para grid = False
#
# - Caso não deseje ver as retas (splines) ligando os pontos da série, mantenha
#
#         add_splines_lines = False.
#
# Caso deseje mostrar as linhas, mude para
#
#       add_splines_lines = True.
#
# ##### ATENÇÃO: NÃO É RECOMENDÁVEL MOSTRAR AS LINHAS CASO OS DADOS NÃO TENHAM SIDO OBTIDOS EM SEQUÊNCIA. TAMBÉM NÃO É RECOMENDÁVEL MOSTRÁ-LAS CASO SE DESEJE OBTER AS CORRELAÇÕES LINEARES
#
# - Note que os valores True e False devem ser escritos exatamente desta forma, primeira letra em maiúscula, e demais minúsculas, e não devem ser colocados entre aspas.
#
#         x1, y1, lab1: série em azul
#         x2, y2, lab2: série em vermelho
#         x3, y3, lab3: série em verde
#         x4, y4, lab4: série em preto
#         x5, y5, lab5: série em magenta
#         x6, y6, lab6: série em amarelo
#
# As cores serão as mesmas para as retas de regressão.
#
# ##### PORÉM, MAIS UMA VEZ: As séries não utilizadas devem ser mantidas em = None
#
# - Exemplos de como chamar a função:
#
#         lin_reg_summary = scatter_plot_lin_reg (x1 = None, y1 = None, x2 = x2, y2 = y, x3 =x3, y3 = y, x4 = x4, y4 = y, x5 = x5, y5 = y, x6 = x6, y6 = y, show_linear_reg = True, grid = True, add_splines_lines = True, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#         -ERRO: não há x1 e y1
#
#         lin_reg_summary = scatter_plot_lin_reg (x1 = x1, y1 = y, x2 = x2, y2 = y, x3 =x3, y3 = y, x4 = x4, y4 = y, x5 = x5, y5 = y, x6 = x6, y6 = y, show_linear_reg = True,  grid = True, add_splines_lines = False, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#
#         lin_reg_summary = scatter_plot_lin_reg (x1 = x1, y1 = y, x2 = x2, y2 = y, x3 =x3, y3 = y, x4 = x4, y4 = y, x5 = x5, y5 = y, show_linear_reg = True,  grid = True, add_splines_lines = False, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#
#         lin_reg_summary = scatter_plot_lin_reg (x1 = x1, y1 = y, x2 = x2, y2 = y, x3 =x3, y3 = y, x4 = x4, y4 = y, show_linear_reg = True, grid = True, add_splines_lines = False, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#
#         lin_reg_summary = scatter_plot_lin_reg (x1 = x1, y1 = y, x2 = x2, y2 = y, x3 =x3, y3 = y, show_linear_reg = True, grid = True, add_splines_lines = False, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#
#         lin_reg_summary = scatter_plot_lin_reg (x1 = x1, y1 = y, x2 = x2, y2 = y, show_linear_reg = True, grid = True, add_splines_lines = False, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#
#         lin_reg_summary = scatter_plot_lin_reg (x1 = x1, y1 = y, show_linear_reg = True, grid = True, add_splines_lines = False, lab1 = "IDADE", lab2 = 'PESO', lab3 = "BATCAR_D", lab4 = "BATCAR_C", lab5 = "BATCAR_M", lab6 = "C_OXIG", titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
#
#         lin_reg_summary = scatter_plot_lin_reg (x1 = x6, y1 = y, show_linear_reg = True, grid = True, add_splines_lines = False, titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)

# %%
## CÉLULA 12: CONSTRUÇÃO DOS GRÁFICOS E OBTENÇÃO DAS CORRELAÇÕES PARA SEUS DADOS

#DEFINA A VARIAVEL x1. Basta substituir o valor entre aspas pelo nome da coluna onde está X1:
x1 = dataset['X1']

#DEFINA A VARIAVEL y1. Basta substituir o valor entre aspas pelo nome da coluna onde está Y1:
y1 = dataset['Y1']

# Na função, substitua um dos valores = None das variáveis x1, x2, ..., x6 por = x1, e o correspondente = None da variável y
#por =y1, de acordo com a cor desejada para o gráfico (como explicado nas instruções acima). 
#O recomendável é colocar x1 = x1, y1 = y1.

#OBSERVAÇÃO: Caso os dados não estejam separados por colunas desta forma, crie séries para armazenar separadamente os dados x,y
#Isto pode ser feito por meio de funções de agregação.
#Clique no botão + no menu superior para criar uma célula que realize esta etapa. Se a célula estiver abaixo da CELL_9, basta
#clicar na seta para cima, do menu superior

"""RÓTULOS, labels e outros valores possíveis

- Existem outras variáveis (x2,y2, x3, y3... etc)? Se existirem, copie e cole as linhas abaixo após as aspas, i.e.,
fora da seção de comentários. Troque os valores entre aspas dentro dos colchetes pelos nomes corretos das colunas no dataset.
Não se equeça de substituir o valor None na função pelo nome correspondente (ou seja: x2 = None deverá ser substituído por 
x2 = x2, ...  e etc, de acordo com os campos presentes e com as cores desejadas).

x2 = dataset['X2']
y2 = dataset['Y2']
x3 = dataset['X3']
y3 = dataset['Y3']
x4 = dataset['X4']
y4 = dataset['Y4']
x5 = dataset['X5']
y5 = dataset['Y5']
x6 = dataset['X6']
y6 = dataset['Y6']

- Existem legendas/rótulos/labels que identifiquem os dados? Se existirem, declare-os entre aspas, conforme as instruções acima.
Por exemplo, lab1 = "loja 1".

"""

lin_reg_summary = scatter_plot_lin_reg (x1 = None, y1 = None, x2 = None, y2 = None, x3 = None, y3 = None, x4 = None, y4 = None, x5 = None, y5 = None, x6 = None, y6 = None, show_linear_reg = True, grid = True, add_splines_lines = True, lab1 = None, lab2 = None, lab3 = None, lab4 = None, lab5 = None, lab6 = None, titulo_eixo_horizontal = None, titulo_eixo_vertical = None, titulo_do_grafico = None)
  
"""
Substitua os demais campos None de acordo com as instruções dadas na CÉLULA 11.
- Os títulos e legendas devem ser fornecidos como um texto entre aspas

"""

lin_reg_summary


"""VOCÊ DESEJA EXPORTAR OS DADOS?
Caso deseje exportar os dados, copie a seguinte linha para o espaço não-vermelho após as aspas. Substitua o endereço pela
pasta onde você deseja salvar seu arquivo. Substitua report pelo nome que deseja para seu arquivo. Mantenha
a extensão csv

lin_reg_summary.to_csv(r"D:\Drive\FM2S\EAD\Green Belt em Python\Machine Learning - módulo 3 - ANN classification\ANN.Class - 1 - user satisfaction\report.csv", index = False)

"""

# %%
## CÉLULA 13: Função de avaliação de correlação linear múltipla

#Execute esta CÉLULA para carregar a função

def multiple_lin_reg (dataframe, y_name, col_x1_name, col_x2_name, col_x3_name = None, col_x4_name = None, col_x5_name = None, col_x6_name = None):
    
    import statsmodels.formula.api as smf
    
    y_lab = y_name
    y = dataframe[y_lab]
    x1_lab = col_x1_name
    x1 = dataframe[x1_lab]
    x2_lab = col_x2_name
    x2 = dataframe[x2_lab]
    
    if not (col_x3_name is None):
        x3_lab = col_x3_name
        x3 = dataframe[x3_lab]
        
        if not (col_x4_name is None):
            x4_lab = col_x4_name
            x4 = dataframe[x4_lab]
            
            if not (col_x5_name is None):
                x5_lab = col_x5_name
                x5 = dataframe[x5_lab]
                
                if not (col_x6_name is None):
                    x6_lab = col_x6_name
                    x6 = dataframe[x6_lab]
                    
                    #regressao em termos das 6 variaveis
                    
                    model_mult_lin_reg = smf.ols(formula='y ~ x1 + x2 + x3 + x4 + x5 + x6', data=dataframe)
                    result = model_mult_lin_reg.fit()
                    results_summary = result.summary()
                    identificadores = "\ny = %s; x1 = %s; x2 = %s; x3 = %s; x4 =%s; x5 = %s; x6 = %s\n" %(y_lab, x1_lab, x2_lab, x3_lab, x4_lab, x5_lab, x6_lab)
                    print(identificadores)
                    modelo = "adjusted model: y = a0 + a1*x1 +a2*x2 + a3*x3 + a4*x4 + a5*x5 +a6*x6\na0 = 'Intercept'; a1, a2,..., a6 = 'coef' of x1, x2,..., x6\n"
                    print(modelo)
                    print(results_summary)
                
                else:
                    #regressao em termos de 5 variaveis
                    
                    model_mult_lin_reg = smf.ols(formula='y ~ x1 + x2 + x3 + x4 + x5', data=dataframe)
                    result = model_mult_lin_reg.fit()
                    results_summary = result.summary()
                    identificadores = "\ny = %s; x1 = %s; x2 = %s; x3 = %s; x4 =%s; x5 = %s\n" %(y_lab, x1_lab, x2_lab, x3_lab, x4_lab, x5_lab)
                    print(identificadores)
                    modelo = "adjusted model: y = a0 + a1*x1 +a2*x2 + a3*x3 + a4*x4 + a5*x5\na0 = 'Intercept'; a1, a2,..., a5 = 'coef' of x1, x2,..., x5\n"
                    print(modelo)
                    print(results_summary)
            
            else:
                #regressao em termos de 4 variaveis
                    
                model_mult_lin_reg = smf.ols(formula='y ~ x1 + x2 + x3 + x4', data=dataframe)
                result = model_mult_lin_reg.fit()
                results_summary = result.summary()
                identificadores = "\ny = %s; x1 = %s; x2 = %s; x3 = %s; x4 =%s\n" %(y_lab, x1_lab, x2_lab, x3_lab, x4_lab)
                print(identificadores)
                modelo = "adjusted model: y = a0 + a1*x1 +a2*x2 + a3*x3 + a4*x4\na0 = 'Intercept'; a1, a2, a3, a4 = 'coef' of x1, x2, x3, x4\n"
                print(modelo)
                print(results_summary)
                    
        else:
            #regressao em termos de 3 variaveis
                    
            model_mult_lin_reg = smf.ols(formula='y ~ x1 + x2 + x3', data=dataframe)
            result = model_mult_lin_reg.fit()
            results_summary = result.summary()
            identificadores = "\ny = %s; x1 = %s; x2 = %s; x3 = %s\n" %(y_lab, x1_lab, x2_lab, x3_lab)
            print(identificadores)
            modelo = "adjusted model: y = a0 + a1*x1 +a2*x2 + a3*x3\na0 = 'Intercept'; a1, a2, a3 = 'coef' of x1, x2, x3\n"
            print(modelo)
            print(results_summary)
        
    else:
        #regressao em termos de 2 variaveis
                    
        model_mult_lin_reg = smf.ols(formula='y ~ x1 + x2', data=dataframe)
        result = model_mult_lin_reg.fit()
        results_summary = result.summary()
        identificadores = "\ny = %s; x1 = %s; x2 = %s\n" %(y_lab, x1_lab, x2_lab)
        print(identificadores)
        modelo = "adjusted model: y = a0 + a1*x1 +a2*x2\na0 = 'Intercept'; a1, a2 = 'coef' of x1, x2\n"
        print(modelo)
        print(results_summary)

# %% [markdown]
# # CÉLULA 14: Regressões lineares múltiplas
#
# ### ATENÇÃO: NÃO EXECUTE ESTA CÉLULA - Ela contém apenas texto explicativo
#
# ###### ATENÇÃO: NECESSÁRIO INSTALAR O PACOTE statsmodels vá ao prompt do Anaconda, digite pip install statsmodels, aperte Enter e aguarde o término da instalação.
#
# - Compare um máximo de 6 fatores simultâneos ou expanda o código, copiando e replicando os índices. Cuidado com as sequências de condicionais.
#
# PARÂMETROS DE ENTRADA:
#
#        multiple_lin_reg(dataframe, y_name, col_x1_name, col_x2_name, col_x3_name = None, col_x4_name = None, col_x5_name = None, col_x6_name = None)
#
# 1) dataframe: dataframe no qual os dados se encontram
#
# 2) y_name: nome da coluna (variável) dos valores Y (variável dependente), que será calculada como função da regressão linear múltipla. Deve vir entre aspas e exatamente igual à forma com que está escrito.
#
#         Exemplos: y_name = "Y"
#         y_name = "Dia"
#
# 3) col_x1_name: nome da coluna (variável) na qual se encontram dados x1. Deve vir entre aspas e exatamente igual à forma com que está escrito.
#
#         Exemplo: col_x1_name = "X1"
#
# 4) col_x2_name: nome da coluna (variável) na qual se encontram dados x1. Deve vir entre aspas e exatamente igual à forma com que está escrito.
#
#         Exemplo: col_x2_name = "X2"
#
# Para usar esta função, são necessários ao menos dois agrupamentos de dados, os quais são inseridos em col_x1_name e col_x2_name, como explicado acima.
#
# - Caso mais variáveis sejam analisadas, preencha, EM SEQUÊNCIA, col_x3_name, col_x4_name, col_x5_name e col_x6_name da mesma forma. Caso não use alguma das variáveis, mantenha ela em None.
#
#         - se apenas 2 variáveis forem utilizadas, mantenha col_x3_name = None,
#         col_x4_name = None, col_x5_name = None e col_x6_name = None
#
#         - se 3 variáveis forem utilizadas, preencha col_x3_name e mantenha
#         col_x4_name = None, col_x5_name = None e col_x6_name = None
#
#         - se 4 variáveis forem utilizadas, preencha col_x3_name e col_x4_name,
#         e mantenha col_x5_name = None e col_x6_name = None
#
#         - se 5 variáveis forem utilizadas, preencha preencha col_x3_name,
#         col_x4_name e col_x5_name, e mantenha col_x6_name = None
#
#         - se 6 variáveis forem utilizadas, preencha todos os campos col_x3_name,
#         col_x4_name, col_x5_name, e col_x6_name
#
# - Em caso de chamar múltiplos gráficos, certifique-se de ter declarado todos os dataframes.
#
# Esta função não retorna dataframes, de modo que não é necessário igualá-la a nenhuma variável. Basta chamá-la, declarando uma linha como:
#
#     multiple_lin_reg(dataframe, y_name, col_x1_name, col_x2_name, col_x3_name = None, col_x4_name = None, col_x5_name = None, col_x6_name = None)
#
# SAÍDA DA FUNÇÃO:
#
# 1) Rodando o código, vemos no console os parâmetros (coeficientes) e estatísticas do modelo. Clique no botão das 3 barras horizontais no canto superior direito do console e selecione “Undock” para ver o console como uma janela separada.
#
# 2) A seguir, maximize a janela, para conseguir visualizar a saída em detalhes.
#
# 3) A tabela mostrada mostrará o R² ajustado na linha "Adj. R-squared" - este parâmetro corrige o R² para a quantidade de valores experimentais e de parâmetros do modelo, conforme explicado no Apêndice.
#
# 4) A tabela mostrará uma coluna 'coef' com os coeficientes do modelo de correlação linear múltipla do tipo Y = a0 + a1X1 + a2X2 + ... + a6X6. O termo 'Intercept' é o coeficiente independente, ou seja, o que não está ligado a nenhuma variável: é o coeficiente a0. Já os demais termos 'coef' são os coeficientes de cada variável: a1, a2,..., a6
#
# Exemplos de como chamar a função: note que esta função permite que os termos não utilizados sejam omitidos. Porém, as demais funções de correlação e série temporal NÃO PERMITEM A OMISSÃO DOS TERMOS.
#
# -Isto só é possível aqui porque a função chama o dataframe como um todo, e o dataframe deve estar separado por colunas. Caso não seja o seu caso:
#
#     1) Filtre o dataframe e obtenha várias séries. Reinicie o índice de cada série.
#     2) Crie um dicionário d = {}, transformando as novas séries em listas de d
#     3) A partir do dicionário, crie um novo dataframe com a função do Pandas: dataframe = pd.DataFrame(data = d)
#
#     multiple_lin_reg (dataframe = dataset, y_name = "TEMPO", col_x1_name = "IDADE", col_x2_name = 'PESO', col_x3_name = "BATCAR_D", col_x4_name = "BATCAR_C", col_x5_name = "BATCAR_M", col_x6_name = "C_OXIG")
#
#     multiple_lin_reg (dataframe = dataset, y_name = "TEMPO", col_x1_name = "IDADE", col_x2_name = 'PESO', col_x3_name = "BATCAR_D", col_x4_name = "BATCAR_C", col_x5_name = "BATCAR_M", col_x6_name = None)
#
#     multiple_lin_reg (dataframe = dataset, y_name = "TEMPO", col_x1_name = "IDADE", col_x2_name = 'PESO', col_x3_name = "BATCAR_D", col_x4_name = "BATCAR_C", col_x5_name = None, col_x6_name = None)
#
#     multiple_lin_reg (dataframe = dataset, y_name = "TEMPO", col_x1_name = "IDADE", col_x2_name = 'PESO', col_x3_name = "BATCAR_D", col_x4_name = None, col_x5_name = None, col_x6_name = None)
#
#     multiple_lin_reg (dataframe = dataset, y_name = "TEMPO", col_x1_name = "IDADE", col_x2_name = 'PESO', col_x3_name = None, col_x4_name = None, col_x5_name = None, col_x6_name = None)
#
#     multiple_lin_reg (dataframe = dataset, y_name = "TEMPO", col_x1_name = "IDADE", col_x2_name = 'PESO')

# %%
## CÉLULA 15: OBTENÇÃO DA CORRELAÇÃO LINEAR MÚLTIPLA PARA SEUS DADOS

#DEFINA O DATAFRAME a ser analisado:
"""
Se desejar analisar apenas uma parte do dataset, utilize o comando a seguir:

dataset = dataset[['col1', 'col2', 'col3']]

entre aspas devem estar os nomes das colunas a ser utilizadas. Acrescente ou remova colunas, conforme a necessidade.

"""
x1 = dataset['X1']

#DEFINA A VARIAVEL y1. Basta substituir o valor entre aspas pelo nome da coluna onde está Y1:
y1 = dataset['Y1']

# Na função, substitua um dos valores = None das variáveis x1, x2, ..., x6 por = x1, e o correspondente = None da variável y
#por =y1, de acordo com a cor desejada para o gráfico (como explicado nas instruções acima). 
#O recomendável é colocar x1 = x1, y1 = y1.

#OBSERVAÇÃO: Caso os dados não estejam separados por colunas desta forma, crie séries para armazenar separadamente os dados x,y
#Isto pode ser feito por meio de funções de agregação.
#Clique no botão + no menu superior para criar uma célula que realize esta etapa. Se a célula estiver abaixo da CELL_9, basta
#clicar na seta para cima, do menu superior


multiple_lin_reg (dataframe = dataset, y_name, col_x1_name, col_x2_name, col_x3_name = None, col_x4_name = None, col_x5_name = None, col_x6_name = None):
    
  
"""
Substitua os demais campos None de acordo com as instruções dadas na CÉLULA 14.
- TODOS OS VALORES DEVEM SER FORNECIDOS ENTRE ASPAS.
- Forneça o nome da coluna y e o nome de cada coluna X utilizada. Por exemplo: y_name = "NOME DA COLUNA Y"

"""
